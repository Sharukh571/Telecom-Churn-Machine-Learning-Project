# %%
get_ipython().system('pip install pymysql')
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

# %%
conn = create_engine('mysql+pymysql://dm_team3:dm_team15119#@18.136.56.185/project_telecom')

# %%
query = 'select * from telecom_churn_data'

# %%
df = pd.read_sql(query,conn)

# %%
df.head()
# Out:
#   columns1 columns2 columns3   columns4 columns5 columns6 columns7 columns8  \
# 0       KS      128      415   382-4657       no      yes       25    265.1
# 1       OH      107      415   371-7191       no      yes       26    161.6
# 2       NJ      137      415   358-1921       no       no        0    243.4
# 3       OH       84      408   375-9999      yes       no        0    299.4
# 4       OK       75      415   330-6626      yes       no        0    166.7
#
#   columns9 columns10    ...    columns12 columns13 columns14 columns15  \
# 0      110     45.07    ...           99     16.78     244.7        91
# 1      123     27.47    ...          103     16.62     254.4       103
# 2      114     41.38    ...          110      10.3     162.6       104
# 3       71      50.9    ...           88      5.26     196.9        89
# 4      113     28.34    ...          122     12.61     186.9       121
#
#   columns16 columns17 columns18 columns19 columns20 columns21
# ...

# %%
df.shape
# Out:
# (4617, 21)

# %%
df.columns = ['state','account_length','area_code','phone','international_plan','vmail_plan','vmail_message','day_mins','day_calls','day_charge','eve_mins','eve_calls','eve_charge','night_mins','night_calls','night_charge','international_mins','international_calls','international_charge','custserv_calls','churn']

# %%
df.head(100)
# Out:
#    state account_length area_code      phone international_plan vmail_plan  \
# 0     KS            128       415   382-4657                 no        yes
# 1     OH            107       415   371-7191                 no        yes
# 2     NJ            137       415   358-1921                 no         no
# 3     OH             84       408   375-9999                yes         no
# 4     OK             75       415   330-6626                yes         no
# 5     AL            118       510   391-8027                yes         no
# 6     MA            121       510   355-9993                 no        yes
# 7     MO            147       415   329-9001                yes         no
# 8     LA            117       408   335-4719                 no         no
# 9     WV            141       415   330-8173                yes        yes
# 10    IN             65       415   329-6603                 no         no
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4617 entries, 0 to 4616
# Data columns (total 21 columns):
# state                   4617 non-null object
# account_length          4617 non-null object
# area_code               4617 non-null object
# phone                   4617 non-null object
# international_plan      4617 non-null object
# vmail_plan              4617 non-null object
# vmail_message           4617 non-null object
# day_mins                4617 non-null object
# day_calls               4617 non-null object
# day_charge              4617 non-null object
# eve_mins                4617 non-null object
# eve_calls               4617 non-null object
# eve_charge              4617 non-null object
# night_mins              4617 non-null object
# night_calls             4617 non-null object
# night_charge            4617 non-null object
# international_mins      4617 non-null object
# international_calls     4617 non-null object
# ...

# %%
#coverting object to int64
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
df.international_plan = enc.fit_transform(df.international_plan)
df.vmail_plan = enc.fit_transform(df.vmail_plan)
df.churn = enc.fit_transform(df.churn)

# %%
#coverting object to int
df.international_calls = df.international_calls.astype('int64')
df.account_length = df.account_length.astype('int64')
df.area_code = df.area_code.astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4617 entries, 0 to 4616
# Data columns (total 21 columns):
# state                   4617 non-null object
# account_length          4617 non-null int64
# area_code               4617 non-null int64
# phone                   4617 non-null object
# international_plan      4617 non-null int64
# vmail_plan              4617 non-null int64
# vmail_message           4617 non-null object
# day_mins                4617 non-null object
# day_calls               4617 non-null object
# day_charge              4617 non-null object
# eve_mins                4617 non-null object
# eve_calls               4617 non-null object
# eve_charge              4617 non-null object
# night_mins              4617 non-null object
# night_calls             4617 non-null object
# night_charge            4617 non-null object
# international_mins      4617 non-null object
# international_calls     4617 non-null int64
# ...

# %%
#converting object to int 
conv_df = ['international_plan','vmail_plan','vmail_message','day_mins','day_calls','day_charge','eve_mins','eve_calls','eve_charge','night_mins','night_calls','night_charge','international_mins','international_charge','custserv_calls']

# %%
df[conv_df] = df[conv_df].apply(pd.to_numeric, errors ='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4617 entries, 0 to 4616
# Data columns (total 21 columns):
# state                   4617 non-null object
# account_length          4617 non-null int64
# area_code               4617 non-null int64
# phone                   4617 non-null object
# international_plan      4617 non-null int64
# vmail_plan              4617 non-null int64
# vmail_message           4617 non-null int64
# day_mins                4617 non-null float64
# day_calls               4617 non-null int64
# day_charge              4617 non-null float64
# eve_mins                4617 non-null float64
# eve_calls               4617 non-null int64
# eve_charge              4617 non-null float64
# night_mins              4617 non-null float64
# night_calls             4617 non-null int64
# night_charge            4617 non-null float64
# international_mins      4617 non-null float64
# international_calls     4617 non-null int64
# ...

# %%
df.head()
# Out:
#   state  account_length  area_code      phone  international_plan  vmail_plan  \
# 0    KS             128        415   382-4657                   0           1
# 1    OH             107        415   371-7191                   0           1
# 2    NJ             137        415   358-1921                   0           0
# 3    OH              84        408   375-9999                   1           0
# 4    OK              75        415   330-6626                   1           0
#
#    vmail_message  day_mins  day_calls  day_charge  ...    eve_calls  \
# 0             25     265.1        110       45.07  ...           99
# 1             26     161.6        123       27.47  ...          103
# 2              0     243.4        114       41.38  ...          110
# 3              0     299.4         71       50.90  ...           88
# 4              0     166.7        113       28.34  ...          122
#
#    eve_charge  night_mins  night_calls  night_charge  international_mins  \
# ...

# %%
#checking for missing values
df.isnull().sum()
# Out:
# state                   0
# account_length          0
# area_code               0
# phone                   0
# international_plan      0
# vmail_plan              0
# vmail_message           0
# day_mins                0
# day_calls               0
# day_charge              0
# eve_mins                0
# eve_calls               0
# eve_charge              0
# night_mins              0
# night_calls             0
# night_charge            0
# international_mins      0
# international_calls     0
# international_charge    0
# custserv_calls          0
# churn                   0
# dtype: int64

# %%
#checking for  duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#checking for outliers
import seaborn as sb
import matplotlib as plt

# %%
get_ipython().run_line_magic('matplotlib', 'inline')
df.plot(kind='box')

# %%
from scipy import stats

# %%
#dropping state column and phone column sice they are different datatypes
df1 = df.drop('state', axis=1)

# %%
df2 = df1.drop('phone', axis=1)

# %%
df2.head()
# Out:
#    account_length  area_code  international_plan  vmail_plan  vmail_message  \
# 0             128        415                   0           1             25
# 1             107        415                   0           1             26
# 2             137        415                   0           0              0
# 3              84        408                   1           0              0
# 4              75        415                   1           0              0
#
#    day_mins  day_calls  day_charge  eve_mins  eve_calls  eve_charge  \
# 0     265.1        110       45.07     197.4         99       16.78
# 1     161.6        123       27.47     195.5        103       16.62
# 2     243.4        114       41.38     121.2        110       10.30
# 3     299.4         71       50.90      61.9         88        5.26
# 4     166.7        113       28.34     148.3        122       12.61
#
#    night_mins  night_calls  night_charge  international_mins  \
# ...

# %%
df2.shape
# Out:
# (4617, 19)

# %%
import matplotlib.pyplot as plt
import seaborn as sb
from matplotlib import rcParams
# %matplotlib inline

# %%
rcParams['figure.figsize'] =10,5
df2.churn.value_counts(sort=False).plot.pie(labels=["NoChurn","Churn"],legend = True, autopct='%1.1f%%',shadow=False)

# %%
rcParams['figure.figsize'] =10,5
df2.churn.value_counts(sort=False).plot.bar
plt.show()

# %%
rcParams['figure.figsize'] =10,5
df2.churn.value_counts().plot(kind='bar')
plt.show()

# %%
df2.describe()
# Out:
#        account_length    area_code  international_plan   vmail_plan  \
# count     4617.000000  4617.000000         4617.000000  4617.000000
# mean       100.645224   437.046350            0.096600     0.267706
# std         39.597194    42.288212            0.295444     0.442812
# min          1.000000   408.000000            0.000000     0.000000
# 25%         74.000000   408.000000            0.000000     0.000000
# 50%        100.000000   415.000000            0.000000     0.000000
# 75%        127.000000   510.000000            0.000000     1.000000
# max        243.000000   510.000000            1.000000     1.000000
#
#        vmail_message     day_mins    day_calls   day_charge     eve_mins  \
# count    4617.000000  4617.000000  4617.000000  4617.000000  4617.000000
# mean        7.849903   180.447152   100.054364    30.676576   200.429088
# std        13.592333    53.983540    19.883027     9.177145    50.557001
# ...

# %%
#correlation between parameters
corr =df2.corr()
rcParams['figure.figsize'] = 9,8
fig = plt.figure()
sb.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values, cmap ='Blues')
corr
# Out:
#                       account_length  area_code  international_plan  \
# account_length              1.000000  -0.020394            0.013948
# area_code                  -0.020394   1.000000            0.039263
# international_plan          0.013948   0.039263            1.000000
# vmail_plan                 -0.004602  -0.003150            0.009278
# vmail_message              -0.012983  -0.002597            0.011596
# day_mins                    0.002002  -0.018900            0.028220
# day_calls                   0.032783  -0.013179            0.007477
# day_charge                  0.001999  -0.018903            0.028223
# eve_mins                   -0.006778   0.011513            0.023740
# eve_calls                   0.015598  -0.011528            0.003360
# eve_charge                 -0.006775   0.011533            0.023740
# night_mins                 -0.002077   0.002794           -0.025951
# night_calls                -0.009482   0.015316            0.007390
# ...

# %%
sb.boxplot(y='custserv_calls', x='churn', data=df2)
plt.title('custsrv_calls vs churn')
plt.show()

# %%
sb.scatterplot(x='day_mins', y='eve_mins', hue='churn', data=df2)
plt.show()

# %%
sb.scatterplot(x='night_mins', y='international_mins', hue='churn', data=df2)
plt.show()

# %%
rcParams['figure.figsize'] = 15,10
pd.crosstab(df.state, df2.churn).plot(kind='bar')
plt.show()

# %%
rcParams['figure.figsize'] = 10,9
pd.crosstab(df2.international_plan, df2.churn).plot(kind='bar')
plt.show()

# %%
rcParams['figure.figsize'] = 10,9
pd.crosstab(df2.vmail_plan, df2.churn).plot(kind='bar')
plt.show()

# %%
plt.subplot(2,2,1)
plt.title('day_charge')
plt.hist(df2['day_charge'])
plt.subplot(2,2,2)
plt.title('eve_charge')
plt.hist(df2['eve_charge'])
plt.subplot(2,2,3)
plt.title('night_charge')
plt.hist(df2['night_charge'])
plt.subplot(2,2,4)
plt.title('international_charge')
plt.hist(df2['international_charge'])
plt.show()

# %%
rcParams['figure.figsize'] = 10,9
pd.crosstab(df2.area_code, df2.churn).plot(kind='bar')
plt.show()

# %%
from collections import Counter

# %%
# Converting Account length into 13 bins each of size 20 days. Check the frequency of each bin
custom_bucket_array = np.linspace(0, 260, 14)
df2['acount_length2'] = pd.cut(df2['account_length'], custom_bucket_array)
Counter(df2['account_length'])
# Out:
# Counter({128: 29,
#          107: 42,
#          137: 39,
#          84: 33,
#          75: 36,
#          118: 33,
#          121: 38,
#          147: 21,
#          117: 48,
#          141: 29,
#          65: 33,
#          74: 40,
#          168: 6,
#          95: 46,
#          62: 24,
#          161: 23,
#          85: 39,
#          93: 54,
#          76: 38,
#          73: 43,
#          77: 35,
#          130: 40,
#          111: 42,
#          132: 37,
#          174: 11,
#          57: 35,
#          54: 22,
#          20: 4,
#          49: 15,
#          142: 24,
#          172: 9,
#          12: 5,
#          72: 38,
#          36: 18,
#          78: 49,
#          136: 33,
#          149: 27,
#          98: 48,
#          135: 31,
#          34: 8,
#          160: 17,
#          64: 36,
#          59: 27,
#          119: 44,
#          97: 38,
#          52: 25,
#          60: 31,
#          10: 3,
#          96: 37,
#          87: 56,
#          81: 39,
# ...

# %%
df2.head()
# Out:
#    account_length  area_code  international_plan  vmail_plan  vmail_message  \
# 0             128        415                   0           1             25
# 1             107        415                   0           1             26
# 2             137        415                   0           0              0
# 3              84        408                   1           0              0
# 4              75        415                   1           0              0
#
#    day_mins  day_calls  day_charge  eve_mins  eve_calls  eve_charge  \
# 0     265.1        110       45.07     197.4         99       16.78
# 1     161.6        123       27.47     195.5        103       16.62
# 2     243.4        114       41.38     121.2        110       10.30
# 3     299.4         71       50.90      61.9         88        5.26
# 4     166.7        113       28.34     148.3        122       12.61
#
#    night_mins  night_calls  night_charge  international_mins  \
# ...

# %%
rcParams['figure.figsize'] = 10,9
pd.crosstab(df2.acount_length2, df2.churn).plot(kind='bar')
plt.show()

# %%
df2.columns
# Out:
# Index(['account_length', 'area_code', 'international_plan', 'vmail_plan',
#        'vmail_message', 'day_mins', 'day_calls', 'day_charge', 'eve_mins',
#        'eve_calls', 'eve_charge', 'night_mins', 'night_calls', 'night_charge',
#        'international_mins', 'international_calls', 'international_charge',
#        'custserv_calls', 'churn', 'acount_length2'],
#       dtype='object')

# %%
X = df2.loc[:,['international_plan','vmail_plan','vmail_message','day_calls','day_charge','eve_calls','eve_charge','night_calls','night_charge','international_calls','international_charge','custserv_calls']]
y = df2.churn

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y, random_state=10)
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
pd.crosstab(y_test, y_predict)
# Out:
# col_0    0   1
# churn
# 0      979  17
# 1      138  21

# %%
from sklearn.metrics import accuracy_score, classification_report
print(accuracy_score(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8658008658008658
#              precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93       996
#           1       0.55      0.13      0.21       159
#
# avg / total       0.83      0.87      0.83      1155

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=30, random_state=15)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=1,
#             oob_score=False, random_state=15, verbose=0, warm_start=False)

# %%
y_predict = model.predict(X_test)
pd.crosstab(y_test, y_predict)
# Out:
# col_0    0    1
# churn
# 0      993    3
# 1       44  115

# %%
from sklearn.metrics import accuracy_score, classification_report
print(accuracy_score(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.9593073593073593
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98       996
#           1       0.97      0.72      0.83       159
#
# avg / total       0.96      0.96      0.96      1155

# %%
from xgboost import XGBClassifier
model = XGBClassifier(booster='gbtree',random_state=25)
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
pd.crosstab(y_test,y_predict)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# col_0    0    1
# churn
# 0      989    7
# 1       38  121

# %%
from sklearn.metrics import accuracy_score, classification_report
print(accuracy_score(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.961038961038961
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98       996
#           1       0.95      0.76      0.84       159
#
# avg / total       0.96      0.96      0.96      1155
